# %%
from jupyter_client.session import json_packer
from matchms.importing import load_from_mgf
import os
from collections import defaultdict
import numpy as np
from collections import Counter
import pandas as pd
import json

# %%
DATA_PATH = "../../../data/MSn"

# %%
spectra = list(load_from_mgf("/Users/macbook/CODE/Majer:MassSpecGym/data/MSn/20241211_msn_library_pos_all_lib_MSn.mgf"))

# %%
# Collect all metadata keys from the spectra
metadata_keys = set()
for spectrum in spectra:
    metadata_keys.update(spectrum.metadata.keys())

print(f"Total unique metadata fields: {len(metadata_keys)}")
print("Metadata fields:")
for key in metadata_keys:
    print(key)
# Out:
# Total unique metadata fields: 39
# Metadata fields:
# acquisition
# quality_explained_signals
# inchi
# precursor_mz
# feature_id
# fragmentation_method
# precursor_purity
# description
# inchi_aux
# other_matched_compounds_names
# quality_explained_intensity
# compound_name
# retention_time
# scans
# collision_energy
# other_matched_compounds
# msn_collision_energies
# usi
# dataset_id
# smiles
# data_collector
# msn_precursor_mzs
# instrument_type
# msn_fragmentation_methods
# ionmode
# formula
# num_peaks
# isolation_window
# msn_isolation_windows
# comment
# charge
# adduct
# ms_level
# quality_chimeric
# spectype
# principal_investigator
# ion_source
# ims_type
# parent_mass

# %%
# Initialize a dictionary to hold lists of values for each metadata field
metadata_values = defaultdict(list)

# Collect values for each metadata field
for spectrum in spectra:
    for key in metadata_keys:
        value = spectrum.metadata.get(key, None)
        metadata_values[key].append(value)

# %%
metadata_frequencies = {}

for key, values in metadata_values.items():
    frequencies = Counter(values)
    metadata_frequencies[key] = frequencies

# %%
top_ten_values = {}

for key, freq_counter in metadata_frequencies.items():
    # Get the ten most common values and their counts
    top_ten = freq_counter.most_common(10)
    top_ten_values[key] = top_ten

# %%
for key in metadata_keys:
    print(f"\nMetadata Field: {key}")
    print("-" * (15 + len(key)))
    top_values = top_ten_values.get(key, [])
    if top_values:
        df = pd.DataFrame(top_values, columns=['Value', 'Frequency'])
        print(df)
    else:
        print("No data available.")
# Out:
# Metadata Field: acquisition
# --------------------------
#    Value  Frequency
# 0  Crude     803405
#
# Metadata Field: quality_explained_signals
# ----------------------------------------
#         Value  Frequency
# 0         1.0     504023
# 1         0.8       8402
# 2        0.75       8325
# 3   0.8333333       8135
# 4  0.85714287       7946
# 5       0.875       7558
# 6   0.8888889       6971
# 7   0.6666667       6782
# 8         0.9       6156
# 9  0.90909094       5533
#
# Metadata Field: inchi
# --------------------
#                                                Value  Frequency
# 0  InChI=1S/C21H24F3N7O/c1-12-28-19(26-2)31-20(29...        541
# 1  InChI=1S/C22H29N7O/c1-15-13-17(29-9-11-30-12-1...        537
# 2  InChI=1S/C22H31NO/c1-16(2)23(17(3)4)14-13-20(1...        464
# 3  InChI=1S/C24H24ClFN2O/c1-15(24(29)28-20-9-6-18...        461
# 4  InChI=1S/C18H18N2O4/c21-15(19-24)10-2-1-3-11-2...        442
# 5  InChI=1S/C12H8N2/c1-3-9-5-6-10-4-2-8-14-12(10)...        442
# 6  InChI=1S/C15H17NO2/c1-11(17)16-9-8-13-5-3-4-12...        429
# 7  InChI=1S/C13H18ClNO2/c1-9-13(16,17-8-12(2,3)15...        395
# 8  InChI=1S/C17H17ClN2O/c1-3-19-16-20-15-10-9-13(...        352
# 9  InChI=1S/C20H26N2O2/c1-3-13-12-22-9-7-14(13)10...        348
#
# Metadata Field: precursor_mz
# ---------------------------
#        Value  Frequency
# 0  327.20670       1114
# 1  325.19105        748
# 2  337.19105        666
# 3  253.08592        657
# 4  342.16998        598
# 5  285.07575        593
# 6  354.13360        589
# 7  327.13393        586
# 8  255.06518        572
# 9  369.18088        562
#
# Metadata Field: feature_id
# -------------------------
#   Value  Frequency
# 0    -1     320555
# 1   237       1629
# 2   232       1618
# 3   239       1617
# 4   234       1614
# 5   223       1613
# 6   235       1610
# 7   249       1609
# 8   224       1609
# 9   229       1609
#
# Metadata Field: fragmentation_method
# -----------------------------------
#   Value  Frequency
# 0  None     702966
# 1   HCD     100439
#
# Metadata Field: precursor_purity
# -------------------------------
#                 Value  Frequency
# 0                 1.0     489780
# 1  0.9765498480139077        132
# 2  0.9790295515756797        128
# 3  0.9646853365986663        120
# 4    0.98001274097899        114
# 5  0.9787300907674353        106
# 6  0.9712652604816693        102
# 7  0.9807845882381755        100
# 8  0.9645163925361915         98
# 9  0.9613901637196582         96
#
# Metadata Field: description
# --------------------------
#                              Value  Frequency
# 0          MCE bioactive compounds     374412
# 1                  MCE 5k scaffold     243033
# 2  NIH NPAC ACONN collection of NP     122837
# 3     OTAVA a-helix peptidomimetic      63123
#
# Metadata Field: inchi_aux
# ------------------------
#                          Value  Frequency
# 0  LQHDJQIMETZMPH-ZBFHGGJFSA-N        541
# 1  OVJBNYKNHXJGSA-UHFFFAOYSA-N        537
# 2  OOGJQPCLVADCPB-HXUWFJFHSA-N        464
# 3  KRTIYQIPSAGSBP-KLAILNCOSA-N        461
# 4  JTDYUFSDZATMKU-UHFFFAOYSA-N        442
# 5  DGEZNRSVGBDHLK-UHFFFAOYSA-N        442
# 6  YJYPHIXNFHFHND-UHFFFAOYSA-N        429
# 7  RCOBKSKAZMVBHT-TVQRCGJNSA-N        395
# 8  IBYCYJFUEJQSMK-UHFFFAOYSA-N        352
# 9  LJOQGZACKSYWCH-WZBLMQSHSA-N        348
#
# Metadata Field: other_matched_compounds_names
# --------------------------------------------
#                                                Value  Frequency
# 0                                               None     789881
# 1                NCGC00380525-01: [M+H-2H2O]+: 0.744        134
# 2                     42895-58-9: [M+H-2H2O]+: 0.744        134
# 3  7-tert-butyl-2-(3-pyridinyl)-1,2,5,6,7,8-hexah...        109
# 4  4-[3-(thiomorpholine-4-carbonyl)piperidin-1-yl...        109
# 5  N-(2,3-dihydro-1,4-benzodioxin-6-ylmethyl)-2-(...        104
# 6  1-[4-(5-{[(pyridin-2-ylmethyl)amino]methyl}fur...        104
# 7                        2034567-82-1: [M+H]+: 0.811        103
# 8                         893929-67-4: [M+H]+: 0.811        103
# 9                         301836-41-9: [M+H]+: 0.885        101
#
# Metadata Field: quality_explained_intensity
# ------------------------------------------
#         Value  Frequency
# 0         1.0     504023
# 1        None       4885
# 2    0.998391          8
# 3   0.9985905          8
# 4   0.9951766          8
# 5   0.9949288          8
# 6   0.9927855          8
# 7   0.9967057          8
# 8  0.99571925          7
# 9   0.9946939          7
#
# Metadata Field: compound_name
# ----------------------------
#                  Value  Frequency
# 0          GSK2256294A        541
# 1          tolterodine        464
# 2           BMS-986205        461
# 3            scriptaid        442
# 4  1,10-phenanthroline        442
# 5          Agomelatine        429
# 6          MPI-0479605        402
# 7           Radafaxine        395
# 8         HYDROQUININE        348
# 9           54827-17-7        348
#
# Metadata Field: retention_time
# -----------------------------
#     Value  Frequency
# 0   75.29       1686
# 1  106.02       1444
# 2   71.06       1249
# 3   79.45       1234
# 4   62.34       1166
# 5   65.46       1119
# 6   78.27       1103
# 7   75.67       1072
# 8   72.90       1053
# 9   62.72       1050
#
# Metadata Field: scans
# --------------------
#   Value  Frequency
# 0    -1     320555
# 1   237       1629
# 2   232       1618
# 3   239       1617
# 4   234       1614
# 5   223       1613
# 6   235       1610
# 7   249       1609
# 8   224       1609
# 9   229       1609
#
# Metadata Field: collision_energy
# -------------------------------
#   Value  Frequency
# 0  None     702966
# 1  60.0      53075
# 2  20.0      24327
# 3  30.0      10574
# 4  15.0       6610
# 5  45.0       5689
# 6  75.0        164
#
# Metadata Field: other_matched_compounds
# --------------------------------------
#   Value  Frequency
# 0  None     789881
# 1     1      13278
# 2     2        246
#
# Metadata Field: msn_collision_energies
# -------------------------------------
#                 Value  Frequency
# 0                None     100439
# 1  [30.0, 40.0, 60.0]      66845
# 2        [30.0, 60.0]      64436
# 3  [45.0, 40.0, 60.0]      44574
# 4        [45.0, 60.0]      40877
# 5        [15.0, 60.0]      40570
# 6  [15.0, 40.0, 60.0]      36361
# 7        [30.0, 40.0]      35905
# 8  [30.0, 40.0, 40.0]      35688
# 9        [30.0, 20.0]      34829
#
# Metadata Field: usi
# ------------------
#                                                Value  Frequency
# 0  mzspec:MSVPLACEHOLDERID:20220613_100AGC_60000R...        274
# 1  mzspec:MSVPLACEHOLDERID:20220601_100AGC_pluska...        268
# 2  mzspec:MSVPLACEHOLDERID:20220613_100AGC_60000R...        267
# 3  mzspec:MSVPLACEHOLDERID:20220613_100AGC_60000R...        261
# 4  mzspec:MSVPLACEHOLDERID:20220613_100AGC_60000R...        256
# 5  mzspec:MSVPLACEHOLDERID:20220613_100AGC_60000R...        255
# 6  mzspec:MSVPLACEHOLDERID:20220613_100AGC_60000R...        252
# 7  mzspec:MSVPLACEHOLDERID:20220613_100AGC_60000R...        250
# 8  mzspec:MSVPLACEHOLDERID:20230404_pluskal_nih_0...        249
# 9  mzspec:MSVPLACEHOLDERID:20220601_pluskal_mce_1...        249
#
# Metadata Field: dataset_id
# -------------------------
#               Value  Frequency
# 0  MSVPLACEHOLDERID     803405
#
# Metadata Field: smiles
# ---------------------
#                                                Value  Frequency
# 0  CNc1nc(N[C@H]2CCC[C@@H](C(=O)NCc3c(C(F)(F)F)cc...        541
# 1  Cc1c(Nc2nc(NC3CCCCC3)c3[nH]cnc3n2)ccc(N2CCOCC2)c1        537
# 2       Cc1cc([C@H](CCN(C(C)C)C(C)C)c2ccccc2)c(O)cc1        464
# 3  C[C@@H](C(=O)Nc1ccc(Cl)cc1)C1CCC(c2c3cc(F)ccc3...        461
# 4            O=C(CCCCCN1C(=O)c2c3c(cccc3ccc2)C1=O)NO        442
# 5                               c1cc2ccc3cccnc3c2nc1        442
# 6                        COc1cc2c(CCNC(C)=O)cccc2cc1        429
# 7            C[C@@H]1NC(C)(C)CO[C@@]1(O)c1cc(Cl)ccc1        395
# 8              CCNC1=Nc2c(cc(Cl)cc2)C(C)(c2ccccc2)O1        352
# 9  CC[C@H]1CN2CC[C@H]1C[C@H]2[C@H](O)c1c2cc(OC)cc...        348
#
# Metadata Field: data_collector
# -----------------------------
#             Value  Frequency
# 0  Corinna Brungs     803405
#
# Metadata Field: msn_precursor_mzs
# --------------------------------
#                                                Value  Frequency
# 0                                               None     100439
# 1  [215.143325805664, 142.077697753906, 152.06217...         18
# 2               [215.143325805664, 187.111785888672]         15
# 3               [215.143325805664, 159.080490112305]         15
# 4               [215.143325805664, 142.077697753906]         15
# 5               [271.096618652344, 229.086730957031]         14
# 6               [271.096618652344, 203.034301757813]         14
# 7               [271.096618652344, 167.034149169922]         14
# 8  [271.096618652344, 167.034149169922, 152.01051...         14
# 9  [271.096618652344, 167.034149169922, 124.01554...         14
#
# Metadata Field: instrument_type
# ------------------------------
#       Value  Frequency
# 0  Orbitrap     803405
#
# Metadata Field: msn_fragmentation_methods
# ----------------------------------------
#                   Value  Frequency
# 0            [HCD, HCD]     331521
# 1       [HCD, HCD, HCD]     329224
# 2                  None     100439
# 3  [HCD, HCD, HCD, HCD]      42221
#
# Metadata Field: ionmode
# ----------------------
#       Value  Frequency
# 0  positive     803405
#
# Metadata Field: formula
# ----------------------
#         Value  Frequency
# 0  C20H26N2O2       1114
# 1  C21H24N2O2        666
# 2  C20H24N2O2        665
# 3  C21H24N2O4        619
# 4  C20H25N3O2        619
# 5    C16H12O5        610
# 6    C17H18O6        607
# 7  C22H23N5O2        602
# 8    C16H12O3        590
# 9   C20H19NO5        589
#
# Metadata Field: num_peaks
# ------------------------
#   Value  Frequency
# 0     3      48840
# 1     2      48356
# 2     4      46192
# 3     5      42231
# 4     6      38025
# 5     7      34998
# 6     8      32269
# 7     9      29496
# 8    10      27052
# 9    11      24619
#
# Metadata Field: isolation_window
# -------------------------------
#                 Value  Frequency
# 0                None     702966
# 1  1.2000000476839432      62697
# 2  1.2000000476840569      29020
# 3      1.200000047684       7086
# 4  1.2000000476841706       1434
# 5  1.2000000476840285        111
# 6  1.2000000476839716         91
#
# Metadata Field: msn_isolation_windows
# ------------------------------------
#                                             Value  Frequency
# 0                       [1.2000000476839432, 2.0]     202728
# 1       [1.2000000476839432, 2.0, 2.200000047684]     190879
# 2                                            None     100439
# 3       [1.2000000476840569, 2.0, 2.200000047684]      99721
# 4                       [1.2000000476840569, 2.0]      98721
# 5                           [1.200000047684, 2.0]      24986
# 6  [1.2000000476839432, 2.0, 2.200000047684, 3.0]      23450
# 7           [1.200000047684, 2.0, 2.200000047684]      21544
# 8  [1.2000000476840569, 2.0, 2.200000047684, 3.0]      12943
# 9    [1.2000000476839432, 2.0, 2.200000047683943]       5694
#
# Metadata Field: comment
# ----------------------
#                                                Value  Frequency
# 0                                               None     428993
# 1  GSK2256294A;1142090-23-0;GSK2256294;GSK-225629...        541
# 2  MPI-0479605;1246529-32-7;N6-Cyclohexyl-N2-(2-m...        537
# 3  BMS-986205;Linrodostat;1923833-60-6;BMS986205;...        461
# 4  scriptaid;287383-59-9;Scriptide;6-(1,3-Dioxo-1...        442
# 5  Radafaxine;192374-14-4;(S,S)-Hydroxy Bupropion...        395
# 6  tolterodine;124937-51-5;(+)-Tolterodine;Tolter...        358
# 7  BRL 15572;BRL-15572;BRL15572;734517-40-9;BRL-1...        340
# 8  300816-15-3;RS 504393;RS-504393;6-Methyl-1'-(2...        310
# 9  CAL-130;1431697-74-3;2-[(1S)-1-[(2-amino-7H-pu...        309
#
# Metadata Field: charge
# ---------------------
#    Value  Frequency
# 0    NaN     582444
# 1    1.0     218534
# 2    2.0       2165
# 3    3.0        254
# 4    4.0          5
# 5   17.0          3
#
# Metadata Field: adduct
# ---------------------
#          Value  Frequency
# 0       [M+H]+     715432
# 1     [M+NH4]+      44502
# 2   [M+H-H2O]+      20063
# 3         [M]+      14733
# 4      [M+Na]+       4051
# 5  [M+H-2H2O]+       3899
# 6     [M-H2O]+        725
#
# Metadata Field: ms_level
# -----------------------
#   Value  Frequency
# 0     3     331521
# 1     4     329224
# 2     2     100439
# 3     5      42221
#
# Metadata Field: quality_chimeric
# -------------------------------
#                  Value  Frequency
# 0               PASSED     791351
# 1             CHIMERIC      11940
# 2  MISSING_MAIN_SIGNAL        114
#
# Metadata Field: spectype
# -----------------------
#                    Value  Frequency
# 0                   None     482850
# 1           ALL_ENERGIES     183365
# 2            SAME_ENERGY     121032
# 3  ALL_MSN_TO_PSEUDO_MS2      16158
#
# Metadata Field: principal_investigator
# -------------------------------------
#            Value  Frequency
# 0  Tomas Pluskal     803405
#
# Metadata Field: ion_source
# -------------------------
#   Value  Frequency
# 0   ESI     803405
#
# Metadata Field: ims_type
# -----------------------
#   Value  Frequency
# 0  none     803405
#
# Metadata Field: parent_mass
# --------------------------
#         Value  Frequency
# 0  326.199428       1114
# 1  336.183778        666
# 2  324.183778        665
# 3  368.173607        619
# 4  339.194677        619
# 5  284.068473        610
# 6  318.110338        607
# 7  389.185175        602
# 8  252.078644        590
# 9  353.126323        589

# %%
metadata_frequencies['quality_explained_signals']
# Out:
# Counter({'1.0': 504023,
#          '0.8': 8402,
#          '0.75': 8325,
#          '0.8333333': 8135,
#          '0.85714287': 7946,
#          '0.875': 7558,
#          '0.8888889': 6971,
#          '0.6666667': 6782,
#          '0.9': 6156,
#          '0.90909094': 5533,
#          '0.9166667': 5335,
#          None: 4885,
#          '0.5': 4741,
#          '0.9230769': 4679,
#          '0.9285714': 4392,
#          '0.93333334': 3995,
#          '0.9375': 3706,
#          '0.9411765': 3402,
#          '0.9444444': 3352,
#          '0.7777778': 3021,
#          '0.94736844': 2922,
#          '0.71428573': 2811,
#          '0.8181818': 2731,
#          '0.95': 2700,
#          '0.6': 2464,
#          '0.95238096': 2440,
#          '0.84615386': 2434,
#          '0.95454544': 2384,
#          '0.8666667': 2159,
#          '0.95652175': 2116,
#          '0.9583333': 1990,
#          '0.96': 1947,
#          '0.88235295': 1918,
#          '0.96153843': 1787,
#          '0.8947368': 1693,
#          '0.962963': 1672,
#          '0.72727275': 1589,
#          '0.33333334': 1528,
#          '0.96428573': 1520,
#          '0.7': 1517,
#          '0.9655172': 1475,
#          '0.9047619': 1457,
#          '0.7692308': 1452,
#          '0.78571427': 1449,
#          '0.96666664': 1300,
#          '0.625': 1293,
#          '0.9130435': 1271,
#          '0.9677419': 1271,
#          '0.8125': 1255,
#          '0.5714286': 1255,
#          '0.8235294': 1249,
#          '0.96875': 1183,
#          '0.969697': 1132,
#          '0.84210527': 1114,
#          '0.92': 1108,
#          '0.9705882': 1029,
#          '0.9722222': 1019,
#          '0.9714286': 1012,
#          '0.85': 1012,
#          '0.9259259': 980,
#          '0.9310345': 974,
#          '0.73333335': 966,
#          '0.9736842': 907,
#          '0.6923077': 893,
#          '0.4': 890,
#          '0.8695652': 881,
#          '0.8636364': 876,
#          '0.7647059': 862,
#          '0.972973': 858,
#          '0.6363636': 822,
#          '0.88': 819,
#          '0.974359': 807,
#          '0.7894737': 804,
#          '0.975': 790,
#          '0.5555556': 781,
#          '0.9354839': 779,
#          '0.25': 760,
#          '0.93939394': 731,
#          '0.97619045': 714,
#          '0.88461536': 714,
#          '0.8095238': 689,
#          '0.9756098': 679,
#          '0.9767442': 659,
#          '0.89285713': 658,
#          '0.8965517': 648,
#          '0.97727275': 644,
#          '0.82608694': 633,
#          '0.94285715': 630,
#          '0.7058824': 612,
#          '0.6875': 602,
#          '0.9032258': 596,
#          '0.7222222': 585,
#          '0.84': 581,
#          '0.64285713': 576,
#          '0.42857143': 572,
#          '0.9459459': 568,
#          '0.9782609': 567,
#          '0.61538464': 562,
#          '0.9777778': 559,
#          '0.7368421': 544,
#          '0.5833333': 544,
#          '0.94871795': 520,
#          '0.9787234': 512,
#          '0.9791667': 509,
#          '0.9512195': 506,
#          '0.8518519': 504,
#          '0.54545456': 502,
#          '0.7916667': 499,
#          '0.90625': 492,
#          '0.7619048': 490,
#          '0.77272725': 473,
#          '0.97959185': 465,
#          '0.86206895': 464,
#          '0.98': 457,
#          '0.9117647': 457,
#          '0.2': 455,
#          '0.9142857': 453,
#          '0.64705884': 450,
#          '0.7826087': 440,
#          '0.95348835': 439,
#          '0.98039216': 436,
#          '0.9811321': 433,
#          '0.87096775': 423,
#          '0.68421054': 406,
#          '0.9807692': 400,
#          '0.8076923': 398,
#          '0.375': 398,
#          '0.8214286': 397,
#          '0.9189189': 396,
#          '0.44444445': 390,
#          '0.98214287': 385,
#          '0.8787879': 380,
#          '0.95555556': 375,
#          '0.92105263': 368,
#          '0.8148148': 368,
#          '0.53846157': 365,
#          '0.9574468': 361,
#          '0.8857143': 357,
#          '0.925': 354,
#          '0.9268293': 351,
#          '0.9302326': 350,
#          '0.2857143': 349,
#          '0.73913044': 340,
#          '0.9814815': 337,
#          '0.82758623': 333,
#          '0.8918919': 328,
#          '0.9818182': 327,
#          '0.9591837': 326,
#          '0.83870965': 321,
#          '0.76': 319,
#          '0.5882353': 317,
#          '0.84375': 317,
#          '0.6315789': 316,
#          '0.8484849': 314,
#          '0.98275864': 306,
#          '0.8974359': 303,
#          '0.98245615': 303,
#          '0.45454547': 298,
#          '0.9830508': 296,
#          '0.9607843': 293,
#          '0.9361702': 292,
#          '0.98333335': 286,
#          '0.16666667': 286,
#          '0.5625': 285,
#          '0.983871': 283,
#          '0.8064516': 283,
#          '0.65': 283,
#          '0.9622642': 282,
#          '0.9318182': 280,
#          '0.9347826': 279,
#          '0.85294116': 279,
#          '0.9649123': 275,
#          '0.46153846': 275,
#          '0.6111111': 275,
#          '0.902439': 274,
#          '0.96363634': 270,
#          '0.79310346': 268,
#          '0.9836066': 267,
#          '0.8611111': 265,
#          '0.8684211': 265,
#          '0.53333336': 265,
#          '0.6818182': 264,
#          '0.7083333': 259,
#          '0.984127': 251,
#          '0.94': 246,
#          '0.82857144': 243,
#          '0.90697676': 240,
#          '0.984375': 237,
#          '0.41666666': 234,
#          '0.7407407': 234,
#          '0.9672131': 233,
#          '0.8648649': 232,
#          '0.6956522': 231,
#          '0.98507464': 230,
#          '0.5294118': 230,
#          '0.8780488': 230,
#          '0.93877554': 227,
#          '0.88372093': 227,
#          '0.8717949': 225,
#          '0.8378378': 224,
#          '0.9111111': 222,
#          '0.88095236': 219,
#          '0.57894737': 217,
#          '0.72': 216,
#          '0.7586207': 216,
#          '0.9848485': 214,
#          '0.9433962': 213,
#          '0.9423077': 213,
#          '0.9661017': 213,
#          '0.76666665': 211,
#          '0.7741935': 209,
#          '0.9852941': 207,
#          '0.14285715': 205,
#          '0.46666667': 205,
#          '0.9846154': 205,
#          '0.61904764': 202,
#          '0.7307692': 202,
#          '0.68': 202,
#          '0.94545454': 200,
#          '0.78125': 194,
#          '0.36363637': 193,
#          '0.9464286': 191,
#          '0.98550725': 190,
#          '0.96825397': 189,
#          '0.7241379': 189,
#          '0.98630136': 186,
#          '0.9148936': 183,
#          '0.59090906': 182,
#          '0.8913044': 181,
#          '0.98571426': 180,
#          '0.9491525': 178,
#          '0.3': 178,
#          '0.9861111': 176,
#          '0.7037037': 175,
#          '0.8055556': 173,
#          '0.8863636': 173,
#          '0.92156863': 171,
#          '0.3846154': 169,
#          '0.9859155': 169,
#          '0.9183673': 168,
#          '0.92727274': 166,
#          '0.81578946': 166,
#          '0.65217394': 166,
#          '0.89361703': 165,
#          '0.9701493': 165,
#          '0.94827586': 165,
#          '0.22222222': 164,
#          '0.9508197': 163,
#          '0.7878788': 162,
#          '0.7419355': 161,
#          '0.85365856': 161,
#          '0.8979592': 159,
#          '0.125': 158,
#          '0.8604651': 157,
#          '0.9866667': 157,
#          '0.82051283': 157,
#          '0.47058824': 155,
#          '0.9692308': 153,
#          '0.9245283': 152,
#          '0.6086956': 151,
#          '0.6785714': 150,
#          '0.8108108': 149,
#          '0.27272728': 149,
#          '0.9710145': 149,
#          '0.9868421': 148,
#          '0.825': 147,
#          '0.9019608': 145,
#          '0.9516129': 144,
#          '0.7837838': 144,
#          '0.9864865': 144,
#          '0.65384614': 143,
#          '0.8372093': 142,
#          '0.7941176': 142,
#          '0.35714287': 142,
#          '0.64': 142,
#          '0.5263158': 141,
#          '0.987013': 140,
#          '0.98734176': 139,
#          '0.55': 136,
#          '0.7948718': 135,
#          '0.9879518': 133,
#          '0.75757575': 133,
#          '0.8958333': 132,
#          '0.4375': 131,
#          '0.953125': 131,
#          '0.9298246': 130,
#          '0.90384614': 130,
#          '0.7714286': 130,
#          '0.8292683': 130,
#          '0.87234044': 129,
#          '0.93650794': 127,
#          '0.6896552': 127,
#          '0.95384616': 126,
#          '0.9074074': 125,
#          '0.97183096': 124,
#          '0.9875': 123,
#          '0.84090906': 122,
#          '0.98717946': 122,
#          '0.7096774': 121,
#          '0.877551': 118,
#          '0.9726027': 118,
#          '0.9876543': 116,
#          '0.95522386': 115,
#          '0.9322034': 114,
#          '0.9056604': 114,
#          '0.9878049': 114,
#          '0.84782606': 113,
#          '0.52380955': 113,
#          '0.79545456': 112,
#          '0.5652174': 112,
#          '0.81395346': 111,
#          '0.93442625': 110,
#          '0.6551724': 110,
#          '0.9882353': 110,
#          '0.7352941': 110,
#          '0.11111111': 110,
#          '0.9594595': 109,
#          '0.97333336': 109,
#          '0.71875': 109,
#          '0.7631579': 108,
#          '0.9137931': 108,
#          '0.9558824': 107,
#          '0.30769232': 107,
#          '0.5925926': 106,
#          '0.80487806': 106,
#          '0.91803277': 105,
#          '0.47368422': 105,
#          '0.8867925': 105,
#          '0.91071427': 105,
#          '0.8541667': 104,
#          '0.9605263': 102,
#          '0.9746835': 102,
#          '0.775': 102,
#          '0.942029': 102,
#          '0.9122807': 102,
#          '0.82222223': 102,
#          '0.84444445': 101,
#          '0.90163934': 101,
#          '0.9589041': 99,
#          '0.8909091': 99,
#          '0.9886364': 98,
#          '0.9883721': 98,
#          '0.9880952': 98,
#          '0.989011': 98,
#          '0.85106385': 97,
#          '0.89830506': 97,
#          '0.5769231': 97,
#          '0.74285716': 96,
#          '0.4117647': 95,
#          '0.9885057': 95,
#          '0.97530866': 95,
#          '0.86': 94,
#          '0.91525424': 94,
#          '0.6296296': 94,
#          '0.56': 94,
#          '0.97402596': 93,
#          '0.5217391': 93,
#          '0.95714283': 92,
#          '0.98876405': 92,
#          '0.42105263': 92,
#          '0.7297297': 92,
#          '0.7567568': 91,
#          '0.93846154': 91,
#          '0.80851066': 91,
#          '0.9577465': 91,
#          '0.67741936': 90,
#          '0.97590363': 90,
#          '0.1': 90,
#          '0.86538464': 90,
#          '0.8627451': 90,
#          '0.7906977': 89,
#          '0.9206349': 88,
#          '0.82978725': 88,
#          '0.921875': 88,
#          '0.45': 87,
#          '0.84313726': 87,
#          '0.8703704': 86,
#          '0.75609756': 86,
#          '0.94520545': 85,
#          '0.7804878': 85,
#          '0.6333333': 85,
#          '0.62068963': 84,
#          '0.9402985': 84,
#          '0.9893617': 84,
#          '0.9775281': 83,
#          '0.5416667': 83,
#          '0.7105263': 83,
#          '0.88135594': 83,
#          '0.26666668': 83,
#          '0.6969697': 82,
#          '0.8367347': 82,
#          '0.9264706': 82,
#          '0.8490566': 82,
#          '0.92424244': 82,
#          '0.6944444': 81,
#          '0.18181819': 81,
#          '0.96103895': 80,
#          '0.47619048': 80,
#          '0.8545455': 79,
#          '0.9647059': 79,
#          '0.8679245': 79,
#          '0.98888886': 79,
#          '0.8727273': 78,
#          '0.81632656': 78,
#          '0.91935486': 76,
#          '0.6451613': 76,
#          '0.09090909': 75,
#          '0.65625': 74,
#          '0.9625': 74,
#          '0.9076923': 74,
#          '0.92957747': 74,
#          '0.3125': 74,
#          '0.92537314': 73,
#          '0.877193': 73,
#          '0.9764706': 73,
#          '0.75555557': 73,
#          '0.23076923': 73,
#          '0.97849464': 73,
#          '0.9480519': 72,
#          '0.96511626': 72,
#          '0.8043478': 72,
#          '0.98913044': 72,
#          '0.3888889': 71,
#          '0.9350649': 71,
#          '0.943662': 71,
#          '0.6756757': 70,
#          '0.8363636': 70,
#          '0.74358976': 69,
#          '0.9892473': 69,
#          '0.3529412': 69,
#          '0.8269231': 69,
#          '0.9894737': 68,
#          '0.6764706': 68,
#          '0.71794873': 68,
#          '0.76744187': 67,
#          '0.96385545': 67,
#          '0.8955224': 67,
#          '0.60714287': 67,
#          '0.9529412': 67,
#          '0.96842104': 66,
#          '0.8833333': 65,
#          '0.978022': 65,
#          '0.87931037': 65,
#          '0.61290324': 65,
#          '0.8039216': 65,
#          '0.9895833': 64,
#          '0.9770115': 64,
#          '0.7027027': 64,
#          '0.79591835': 63,
#          '0.99': 63,
#          '0.8448276': 63,
#          '0.83928573': 63,
#          '0.78723407': 63,
#          '0.7708333': 63,
#          '0.6857143': 63,
#          '0.6571429': 62,
#          '0.7380952': 62,
#          '0.88709676': 62,
#          '0.96629214': 62,
#          '0.890625': 62,
#          '0.21428572': 62,
#          '0.15384616': 62,
#          '0.94666666': 61,
#          '0.86885244': 61,
#          '0.82': 61,
#          '0.96202534': 61,
#          '0.9897959': 61,
#          '0.9518072': 61,
#          '0.78431374': 61,
#          '0.52': 61,
#          '0.9358974': 61,
#          '0.9390244': 60,
#          '0.9896907': 60,
#          '0.9493671': 60,
#          '0.5862069': 60,
#          '0.5185185': 60,
#          '0.55172414': 60,
#          '0.8596491': 59,
#          '0.9907407': 59,
#          '0.9634146': 59,
#          '0.8035714': 59,
#          '0.8852459': 59,
#          '0.45833334': 59,
#          '0.8113208': 58,
#          '0.9305556': 58,
#          '0.9324324': 58,
#          '0.97894734': 58,
#          '0.083333336': 58,
#          '0.93421054': 58,
#          '0.8301887': 58,
#          '0.86440676': 58,
#          '0.989899': 58,
#          '0.7209302': 57,
#          '0.89705884': 57,
#          '0.9104478': 57,
#          '0.74418604': 57,
#          '0.96590906': 57,
#          '0.84745765': 57,
#          '0.852459': 56,
#          '0.9220779': 56,
#          '0.97979796': 56,
#          '0.725': 56,
#          '0.8305085': 56,
#          '0.86153847': 56,
#          '0.7755102': 56,
#          '0.86567163': 55,
#          '0.47826087': 55,
#          '0.89855075': 55,
#          '0.91549295': 54,
#          '0.59375': 54,
#          '0.8939394': 54,
#          '0.7659575': 54,
#          '0.6486486': 54,
#          '0.78846157': 54,
#          '0.96703297': 53,
#          '0.8769231': 53,
#          '0.92753625': 52,
#          '0.9315069': 52,
#          '0.94186044': 52,
#          '0.76086956': 52,
#          '0.9680851': 52,
#          '0.51724136': 52,
#          '0.9673913': 51,
#          '0.7924528': 51,
#          '0.8245614': 51,
#          '0.36842105': 51,
#          '0.93670887': 51,
#          '0.7173913': 51,
#          '0.9425287': 50,
#          '0.31578946': 50,
#          '0.954023': 50,
#          '0.91780823': 50,
#          '0.99038464': 50,
#          '0.4347826': 50,
#          '0.70454544': 49,
#          '0.53571427': 49,
#          '0.8360656': 49,
#          '0.61764705': 49,
#          '0.9506173': 48,
#          '0.99019605': 48,
#          '0.880597': 48,
#          '0.73170733': 48,
#          '0.65789473': 47,
#          '0.9550562': 47,
#          '0.939759': 47,
#          '0.48': 47,
#          '0.6060606': 47,
#          '0.95604396': 47,
#          '0.70731705': 47,
#          '0.90140843': 46,
#          '0.92941177': 46,
#          '0.9904762': 46,
#          '0.9404762': 46,
#          '0.68292683': 46,
#          '0.99065423': 46,
#          '0.9054054': 46,
#          '0.8923077': 46,
#          '0.3809524': 45,
#          '0.6904762': 45,
#          '0.99115044': 45,
#          '0.8196721': 44,
#          '0.990566': 44,
#          '0.90789473': 44,
#          '0.828125': 44,
#          '0.8730159': 44,
#          '0.29411766': 44,
#          '0.82258064': 44,
#          '0.990991': 44,
#          '0.9027778': 44,
#          '0.85915494': 44,
#          '0.9240506': 43,
#          '0.6388889': 43,
#          '0.9041096': 43,
#          '0.9910714': 43,
#          '0.94382024': 43,
#          '0.99130434': 43,
#          '0.13333334': 43,
#          '0.9125': 43,
#          '0.071428575': 43,
#          '0.8507463': 42,
#          '0.75510204': 42,
#          '0.58064514': 42,
#          '0.07692308': 42,
#          '0.9909091': 42,
#          '0.8933333': 42,
#          '0.884058': 41,
#          '0.95789474': 41,
#          '0.990099': 41,
#          '0.85507244': 41,
#          '0.99029124': 41,
#          '0.9611651': 41,
#          '0.8548387': 41,
#          '0.56666666': 41,
#          '0.82539684': 41,
#          '0.76785713': 41,
#          '0.9813084': 40,
#          '0.859375': 40,
#          '0.89041096': 40,
#          '0.6216216': 40,
#          '0.74509805': 40,
#          '0.4090909': 40,
#          '0.6585366': 40,
#          '0.9908257': 40,
#          '0.980198': 40,
#          '0.6888889': 40,
#          '0.8358209': 40,
#          '0.9382716': 40,
#          '0.91358024': 39,
#          '0.97': 39,
#          '0.675': 39,
#          '0.87323946': 39,
#          '0.9066667': 39,
#          '0.8630137': 39,
#          '0.74': 39,
#          '0.9809524': 39,
#          '0.8103448': 38,
#          '0.4827586': 38,
#          '0.97938144': 38,
#          '0.35': 38,
#          '0.7962963': 38,
#          '0.796875': 38,
#          '0.5945946': 38,
#          '0.9113924': 38,
#          '0.78': 38,
#          '0.94505495': 37,
#          '0.8088235': 37,
#          '0.96938777': 37,
#          '0.87142855': 37,
#          '0.93406594': 37,
#          '0.89873415': 37,
#          '0.96907216': 36,
#          '0.8783784': 36,
#          '0.23529412': 36,
#          '0.9519231': 36,
#          '0.8382353': 36,
#          '0.97029704': 36,
#          '0.2777778': 36,
#          '0.98058254': 36,
#          '0.86764705': 36,
#          '0.8135593': 35,
#          '0.5483871': 35,
#          '0.94623655': 35,
#          '0.42307693': 35,
#          '0.7254902': 35,
#          '0.7446808': 35,
#          '0.81666666': 35,
#          '0.5588235': 35,
#          '0.9708738': 35,
#          '0.7291667': 35,
#          '0.9456522': 34,
#          '0.8961039': 34,
#          '0.62857145': 34,
#          '0.7936508': 34,
#          '0.91463417': 34,
#          '0.9587629': 34,
#          '0.76363635': 34,
#          '0.2631579': 33,
#          '0.9325843': 33,
#          '0.7735849': 33,
#          '0.754717': 33,
#          '0.9102564': 33,
#          '0.64102566': 33,
#          '0.3043478': 33,
#          '0.8815789': 33,
#          '0.991453': 33,
#          '0.39130434': 33,
#          '0.80701756': 33,
#          '0.8831169': 32,
#          '0.9915254': 32,
#          '0.8513514': 32,
#          '0.9569892': 32,
#          '0.97196263': 32,
#          '0.7592593': 32,
#          '0.963964': 32,
#          '0.06666667': 32,
#          '0.7111111': 32,
#          '0.9484536': 32,
#          '0.74545455': 32,
#          '0.57575756': 32,
#          '0.9913793': 32,
#          '0.95327103': 31,
#          '0.70212764': 31,
#          '0.8902439': 31,
#          '0.78333336': 31,
#          '0.90588236': 31,
#          '0.7234042': 31,
#          '0.9306931': 31,
#          '0.75438595': 31,
#          '0.4642857': 31,
#          '0.9727273': 30,
#          '0.9381443': 30,
#          '0.8552632': 30,
#          '0.97115386': 30,
#          '0.0625': 30,
#          '0.99122804': 30,
#          '0.7719298': 30,
#          '0.886076': 30,
#          '0.9195402': 30,
#          '0.8767123': 30,
#          '0.9468085': 30,
#          '0.982906': 30,
#          '0.9431818': 30,
#          '0.9918699': 30,
#          '0.6744186': 30,
#          '0.64444447': 30,
#          '0.9247312': 29,
#          '0.90361446': 29,
#          '0.8873239': 29,
#          '0.75409836': 29,
#          '0.6511628': 29,
#          '0.6097561': 29,
#          '0.6052632': 29,
#          '0.96190476': 29,
#          '0.9186047': 29,
#          '0.44': 29,
#          '0.8153846': 29,
#          '0.37037036': 29,
#          '0.7346939': 29,
#          '0.84126985': 29,
#          '0.7169811': 29,
#          '0.8607595': 29,
#          '0.4814815': 29,
#          '0.6981132': 29,
#          '0.7758621': 28,
#          '0.9745763': 28,
#          '0.98373985': 28,
#          '0.9270833': 28,
#          '0.63414633': 28,
#          '0.95098037': 28,
#          '0.9724771': 28,
#          '0.67391306': 28,
#          '0.9831933': 28,
#          '0.66': 28,
#          '0.7358491': 28,
#          '0.9652174': 28,
#          '0.9919355': 28,
#          '0.92783505': 28,
#          '0.9255319': 27,
#          '0.7818182': 27,
#          '0.9734513': 27,
#          '0.9292929': 27,
#          '0.3478261': 27,
#          '0.8988764': 27,
#          '0.95535713': 27,
#          '0.8625': 27,
#          '0.9339623': 27,
#          '0.9834711': 27,
#          '0.65957445': 27,
#          '0.6976744': 27,
#          '0.90123457': 27,
#          '0.8271605': 27,
#          '0.9489796': 27,
#          '0.7903226': 27,
#          '0.94949496': 27,
#          '0.99224806': 27,
#          '0.959596': 27,
#          '0.96039605': 27,
#          '0.99206346': 27,
#          '0.46875': 27,
#          '0.53125': 27,
#          '0.9479167': 26,
#          '0.1875': 26,
#          '0.98165137': 26,
#          '0.90217394': 26,
#          '0.8032787': 26,
#          '0.92771083': 26,
#          '0.9514563': 26,
#          '0.82191783': 26,
#          '0.05263158': 26,
#          '0.15789473': 26,
#          '0.9823009': 26,
#          '0.5609756': 26,
#          '0.7887324': 26,
#          '0.78688526': 26,
#          '0.8915663': 25,
#          '0.92045456': 25,
#          '0.90804595': 25,
#          '0.99159664': 25,
#          '0.984252': 25,
#          '0.9101124': 25,
#          '0.3181818': 25,
#          '0.92134833': 25,
#          '0.91764706': 25,
#          '0.84931505': 25,
#          '0.981982': 25,
#          '0.44827586': 25,
#          '0.41379312': 25,
#          '0.779661': 25,
#          '0.85333335': 24,
#          '0.91566265': 24,
#          '0.9528302': 24,
#          '0.9626168': 24,
#          '0.93636364': 24,
#          '0.9010989': 24,
#          '0.7846154': 24,
#          '0.9222222': 24,
#          '0.7090909': 24,
#          '0.8472222': 24,
#          '0.8450704': 24,
#          '0.6458333': 24,
#          '0.62222224': 24,
#          '0.83076924': 24,
#          '0.9368421': 24,
#          '0.8309859': 24,
#          '0.8405797': 24,
#          '0.8765432': 24,
#          '0.43333334': 24,
#          '0.97692305': 24,
#          '0.90816325': 23,
#          '0.6136364': 23,
#          '0.992': 23,
#          '0.976': 23,
#          '0.9741379': 23,
#          '0.8115942': 23,
#          '0.89534885': 23,
#          '0.96330273': 23,
#          '0.516129': 23,
#          '0.9120879': 23,
#          '0.21052632': 23,
#          '0.92391306': 23,
#          '0.7627119': 23,
#          '0.94174755': 23,
#          '0.67346936': 23,
#          '0.8414634': 23,
#          '0.1764706': 23,
#          '0.84415585': 23,
#          '0.79710144': 23,
#          '0.65909094': 23,
#          '0.9223301': 22,
#          '0.7457627': 22,
#          '0.93': 22,
#          '0.36': 22,
#          '0.5151515': 22,
#          '0.9918033': 22,
#          '0.93203884': 22,
#          '0.81333333': 22,
#          '0.9716981': 22,
#          '0.8169014': 22,
#          '0.9927536': 22,
#          '0.48387095': 22,
#          '0.9313725': 22,
#          '0.7536232': 22,
#          '0.8701299': 22,
#          '0.9139785': 22,
#          '0.7580645': 22,
#          '0.5675676': 22,
#          '0.7794118': 22,
#          '0.7966102': 22,
#          '0.94690263': 22,
#          '0.8082192': 22,
#          '0.51428574': 22,
#          '0.84810126': 22,
#          '0.984': 22,
#          '0.8901099': 22,
#          '0.29166666': 22,
#          '0.973913': 21,
#          '0.8817204': 21,
#          '0.8227848': 21,
#          '0.94392526': 21,
#          '0.2173913': 21,
#          '0.7763158': 21,
#          '0.26086956': 21,
#          '0.4516129': 21,
#          '0.8910891': 21,
#          '0.87341774': 21,
#          '0.54285717': 21,
#          '0.85542166': 21,
#          '0.99230766': 21,
#          '0.9917355': 21,
#          '0.96638656': 21,
#          '0.9826087': 21,
#          '0.79268295': 21,
#          '0.87058824': 21,
#          '0.8194444': 21,
#          '0.11764706': 21,
#          '0.4074074': 21,
#          '0.5405405': 21,
#          '0.6851852': 21,
#          '0.98540145': 21,
#          '0.96460176': 20,
#          '0.765625': 20,
#          '0.75384617': 20,
#          '0.8674699': 20,
#          '0.7746479': 20,
#          '0.60465115': 20,
#          '0.8101266': 20,
#          '0.9916667': 20,
#          '0.8942308': 20,
#          '0.9844961': 20,
#          '0.992126': 20,
#          '0.96850395': 20,
#          '0.7413793': 20,
#          '0.23809524': 20,
#          '0.86585367': 20,
#          '0.99242425': 20,
#          '0.4857143': 20,
#          '0.55263156': 20,
#          '0.75714284': 20,
#          '0.95614034': 20,
#          '0.5277778': 20,
#          '0.9478261': 19,
#          '0.8243243': 19,
#          '0.9579832': 19,
#          '0.4848485': 19,
#          '0.9537037': 19,
#          '0.92241377': 19,
#          '0.91752577': 19,
#          '0.94495416': 19,
#          '0.95726496': 19,
#          '0.8795181': 19,
#          '0.74603176': 19,
#          '0.86170214': 19,
#          '0.7704918': 19,
#          '0.95049506': 19,
#          '0.73015875': 19,
#          '0.9108911': 19,
#          '0.94262296': 19,
#          '0.8356164': 19,
#          '0.89320385': 19,
#          '0.86904764': 19,
#          '0.1904762': 19,
#          '0.8433735': 19,
#          '0.9557522': 19,
#          '0.6603774': 19,
#          '0.9576271': 19,
#          '0.9747899': 19,
#          '0.8764045': 19,
#          '0.85897434': 19,
#          '0.8875': 19,
#          '0.9752066': 19,
#          '0.90425533': 19,
#          '0.39285713': 19,
#          '0.32': 19,
#          '0.7972973': 18,
#          '0.9157895': 18,
#          '0.3548387': 18,
#          '0.71153843': 18,
#          '0.58536583': 18,
#          '0.6727273': 18,
#          '0.76811594': 18,
#          '0.71666664': 18,
#          '0.72131145': 18,
#          '0.88505745': 18,
#          '0.9369369': 18,
#          '0.627907': 18,
#          '0.82894737': 18,
#          '0.7205882': 18,
#          '0.9716312': 18,
#          '0.9925926': 18,
#          '0.68085104': 18,
#          '0.6792453': 18,
#          '0.9930556': 18,
#          '0.6964286': 18,
#          '0.8030303': 18,
#          '0.5681818': 18,
#          '0.9238095': 17,
#          '0.9380531': 17,
#          '0.82666665': 17,
#          '0.9921875': 17,
#          '0.954955': 17,
#          '0.8375': 17,
#          '0.44117647': 17,
#          '0.85882354': 17,
#          '0.63461536': 17,
#          '0.9082569': 17,
#          '0.82417583': 17,
#          '0.05882353': 17,
#          '0.8208955': 17,
#          '0.37931034': 17,
#          '0.79452056': 17,
#          '0.93162394': 17,
#          '0.93043476': 17,
#          '0.9263158': 17,
#          '0.25925925': 17,
#          '0.85057473': 17,
#          '0.8028169': 17,
#          '0.9207921': 17,
#          '0.40625': 17,
#          '0.88659793': 17,
#          '0.99310344': 17,
#          '0.97761196': 17,
#          '0.9758065': 17,
#          '0.91588783': 17,
#          '0.8142857': 17,
#          '0.99270076': 17,
#          '0.5365854': 17,
#          '0.74647886': 17,
#          '0.9862069': 16,
#          '0.31034482': 16,
#          '0.80597013': 16,
#          '0.9051724': 16,
#          '0.9296875': 16,
#          '0.7017544': 16,
#          '0.83116883': 16,
#          '0.5897436': 16,
#          '0.89719623': 16,
#          '0.79012346': 16,
#          '0.9858156': 16,
#          '0.97540987': 16,
#          '0.6938776': 16,
#          ...})

# %%
# Serialize data into file:
# json.dump( metadata_frequencies, open( os.path.join(DATA_PATH, "20240916_metadata_frequencies_all_pos.json"), 'w' ) )

# %% [markdown]
# ## Canonization Analyzis

# %%
import os
import json
from typing import List, Dict, Set, Tuple, Union
from massspecgym.tools.analyzers import analyze_canonical_smiles, compare_canonical_smiles
from rdkit import Chem
import time

# %%
# Use old one to map old SMILES before canonization to PubChem and RDKit
mgf_path = "/Users/macbook/CODE/Majer:MassSpecGym/data/MSn/20240929_msn_library_pos_all_lib_MSn.mgf"
json_path = "/Users/macbook/CODE/Majer:MassSpecGym/data/MSn/smiles_canonicalization_all.json"

# %%
with open(json_path, 'r') as f:
    smiles_dict = json.load(f)

# %%
spectra = list(load_from_mgf(mgf_path))

# %%
smiles_in_spectra = set()
for spectrum in spectra:
    smiles = spectrum.metadata.get('smiles') or spectrum.metadata.get('SMILES')
    if smiles:
        smiles_in_spectra.add(smiles)

# %%
print(f"Total unique SMILES in spectra: {len(smiles_in_spectra)}")
print(f"Total SMILES in canonicalization PubChem dict: {len(smiles_dict)}")


problematic_smiles = smiles_in_spectra - set(smiles_dict.keys())
print(f"Found {len(problematic_smiles)} problematic OLD SMILES not in the canonicalization dict.")
# Out:
# Total unique SMILES in spectra: 14008
# Total SMILES in canonicalization dict: 14008
# Found 0 problematic OLD SMILES not in the canonicalization dict.

# %%
_, canonical_smiles_set_rdkit, invalid_smiles_set_rdkit = analyze_canonical_smiles(spectra)
# Out:
# === SMILES Processing Statistics ===
# Mode: SPECTRA
# Total SMILES extracted: 14008
# Unique original SMILES: 14008
# Unique canonical SMILES: 14008
# Number of invalid SMILES: 0
# Number of SMILES unchanged after RDKit canonicalization: 6447
# ====================================

# %%
# Extract PubChem canonical SMILES from the JSON dictionary
canonical_smiles_set_pubchem = set(smiles_dict.values())

print(f"Total unique PubChem canonical SMILES: {len(canonical_smiles_set_pubchem)}")
print(f"Total unique RDKit canonical SMILES: {len(canonical_smiles_set_rdkit)}")

# Check if both sets are identical
if canonical_smiles_set_pubchem == canonical_smiles_set_rdkit:
    print("\nPubChem and RDKit canonical SMILES sets are identical.")
else:
    print("\nPubChem and RDKit canonical SMILES sets differ.")

    pubchem_not_rdkit = canonical_smiles_set_pubchem - canonical_smiles_set_rdkit
    print(f"\n SMILES in PubChem but not in RDKit: {len(pubchem_not_rdkit)}")

    rdkit_not_pubchem = canonical_smiles_set_rdkit - canonical_smiles_set_pubchem
    print(f"\n SMILES in RDKit but not in PubChem: {len(rdkit_not_pubchem)}")

    overlap = canonical_smiles_set_pubchem.intersection(canonical_smiles_set_rdkit)
    print(f"\n Number of overlapping canonical SMILES: {len(overlap)}")
# Out:
# Total unique PubChem canonical SMILES: 14008
# Total unique RDKit canonical SMILES: 14008
#
# PubChem and RDKit canonical SMILES sets differ.
#
#  SMILES in PubChem but not in RDKit: 13944
#
#  SMILES in RDKit but not in PubChem: 13944
#
#  Number of overlapping canonical SMILES: 64

# %%
compare_canonical_smiles(mgf_path, json_path)
# Out:
# To make sense of analyzis is recommended to use version of dataset without canonizations, date before 29/09
# Loading spectra from MGF file...
# Loaded 803405 spectra.
#
# Loading PubChem canonical SMILES from JSON...
# Loaded canonical SMILES dictionary with 14008 entries.
#
# Extracting unique SMILES from spectra...
# Total unique SMILES in spectra: 14008
# Total SMILES in canonicalization dict (PubChem): 14008
#
# Found 0 problematic SMILES not in the canonicalization dict.
#
# Analyzing canonical SMILES with RDKit...
# === SMILES Processing Statistics ===
# Mode: SPECTRA
# Total SMILES extracted: 14008
# Unique original SMILES: 14008
# Unique canonical SMILES: 14008
# Number of invalid SMILES: 0
# Number of SMILES unchanged after RDKit canonicalization: 6447
# ====================================
#
# Total unique RDKit canonical SMILES: 14008
# Total invalid SMILES by RDKit: 0
#
# Total unique PubChem canonical SMILES: 14008
#
# Comparing PubChem and RDKit canonical SMILES sets...
#
#  PubChem and RDKit canonical SMILES sets differ.
#
#  SMILES in PubChem but not in RDKit: 13944
#
#  SMILES in RDKit but not in PubChem: 13944
#
#  Number of overlapping canonical SMILES: 64
#
# Mapping original SMILES to PubChem canonical SMILES...
# Mapping complete.
#
# Mapping original SMILES to RDKit canonical SMILES...
# Mapping complete.
#
# Comparing PubChem and RDKit canonical SMILES per original SMILES...
#
# === Detailed Comparison Statistics ===
# Total SMILES processed: 14008
# Successfully canonicalized by both PubChem and RDKit: 7561
# Successfully canonicalized by both but differing: 7561
# Canonicalization failed by PubChem but succeeded by RDKit: 0
# Canonicalization failed by RDKit but succeeded by PubChem: 6383
# Canonicalization failed by both PubChem and RDKit: 64
# Total differing canonical SMILES: 7561
#
# === SMILES with Differing Canonical Forms ===
# Original SMILES: CCc1ccccc1-n1nnnc1SCC(=O)NCCc1c[nH]c2c1ccc(OC)c2
# PubChem canonical: CCC1=CC=CC=C1N2C(=NN=N2)SCC(=O)NCCC3=CNC4=C3C=CC(=C4)OC
# RDKit canonical: CCc1ccccc1-n1nnnc1SCC(=O)NCCc1c[nH]c2cc(OC)ccc12
#
# Original SMILES: Cc1cc(OC(=O)c2c(O)c(C)c(O)c(C)c2C)cc(O)c1C(=O)NC(C(=O)O)C(C)O
# PubChem canonical: CC1=CC(=CC(=C1C(=O)NC(C(C)O)C(=O)O)O)OC(=O)C2=C(C(=C(C(=C2C)C)O)C)O
# RDKit canonical: Cc1cc(OC(=O)c2c(C)c(C)c(O)c(C)c2O)cc(O)c1C(=O)NC(C(=O)O)C(C)O
#
# Original SMILES: CCCCC[C@H](O)CC[C@@H]1[C@H]2Cc3c(C[C@H]2C[C@H]1O)c(OCC(=O)O)ccc3
# PubChem canonical: CCCCC[C@@H](CC[C@H]1[C@@H](C[C@H]2[C@@H]1CC3=C(C2)C(=CC=C3)OCC(=O)O)O)O
# RDKit canonical: CCCCC[C@H](O)CC[C@@H]1[C@H]2Cc3cccc(OCC(=O)O)c3C[C@H]2C[C@H]1O
#
# Original SMILES: CC(C)=CCc1c(-c2c(O)cc(O)cc2)oc2c(c(O)cc3c2C=CC(C)(C)O3)c1=O
# PubChem canonical: CC(=CCC1=C(OC2=C(C1=O)C(=CC3=C2C=CC(O3)(C)C)O)C4=C(C=C(C=C4)O)O)C
# RDKit canonical: CC(C)=CCc1c(-c2ccc(O)cc2O)oc2c3c(cc(O)c2c1=O)OC(C)(C)C=C3
#
# Original SMILES: COc1c2oc(-c3cc(O)c(O)cc3)c(O)c(=O)c2c(O)cc1O[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O
# PubChem canonical: COC1=C(C=C(C2=C1OC(=C(C2=O)O)C3=CC(=C(C=C3)O)O)O)O[C@H]4[C@@H]([C@H]([C@@H]([C@H](O4)CO)O)O)O
# RDKit canonical: COc1c(O[C@@H]2O[C@H](CO)[C@@H](O)[C@H](O)[C@H]2O)cc(O)c2c(=O)c(O)c(-c3ccc(O)c(O)c3)oc12
#
# === Comparison Complete ===
